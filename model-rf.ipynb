# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow -U tensorflow_decision_forests > /dev/null

# %%
import pandas as pd
import numpy as np
from numpy import dtype
import tensorflow_decision_forests as tfdf
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report

# %%
cols = {
    
    # 'ts': int,
    # 'src_ip': 'category',
    'src_port': float,
    # 'dst_ip': 'category',
    'dst_port': float,
    'proto': 'category',
    # 'service': 'category',
    # 'duration': float,
    # 'src_bytes': float,
    # 'dst_bytes': float,
    # 'conn_state': 'category',
    # 'missed_bytes': float,

    # 'src_pkts': float,
    # 'src_ip_bytes': float,
    # 'dst_pkts': float,
    # 'dst_ip_bytes': float,

    # 'dns_query': 'category',
    # 'dns_qclass': float,
    # 'dns_qtype': float,
    # 'dns_rcode': float,
    # 'dns_AA': float, #bool
    # 'dns_RD': float, #bool
    # 'dns_rejected': float, #bool

    # 'ssl_version': 'category',
    # 'ssl_cipher': 'category',
    # 'ssl_resumed': float, #bool
    # 'ssl_established': float, #bool
    # 'ssl_subject': 'category',
    # 'ssl_issuer': 'category',

    # 'http_trans_depth': float,
    # 'http_method': 'category',
    # 'http_uri': 'category',
    # 'http_version': 'category',
    # 'http_request_body_len': float,
    # 'http_response_body_len': float,
    # 'http_status_code': float,
    # 'http_user_agent': 'category',
    # 'http_orig_mime_types': 'category',
    # 'http_resp_mime_types': 'category',

    # 'weird_name': 'category',
    # 'weird_addl': 'category',
    # 'weird_notice': float, #bool

    'label': int

}

def bool_to_number(x: str) -> float:
  if x == 'T':
    return 1
  elif x == 'F':
    return 0
  elif x == '-':
    return 0.5
  else:
    raise x

converters = {
    'dns_AA': bool_to_number,
    'dns_RD': bool_to_number,
    'dns_rejected': bool_to_number,
    'ssl_resumed': bool_to_number,
    'ssl_established': bool_to_number,
    'weird_notice': bool_to_number
}

# %%
df = pd.read_csv('/content/drive/Shareddrives/datasci/ton_iot/Train_Test_Network.csv',
                      sep=',',
                      header=0,
                      dtype=cols,
                      usecols=list(cols.keys()),
                      converters=converters,
                      na_values=['-'])

# %%
df
# Out:
#         src_port  dst_port proto  label
# 0         1883.0   52976.0   tcp      0
# 1        47260.0   15600.0   udp      0
# 2         1880.0   51782.0   tcp      0
# 3        34296.0   10502.0   tcp      0
# 4        46608.0      53.0   udp      0
# ...          ...       ...   ...    ...
# 461038   33108.0      80.0   tcp      1
# 461039   37242.0     443.0   tcp      1
# 461040    4444.0   49178.0   tcp      1
# 461041   60816.0     443.0   tcp      1
# 461042   41054.0     443.0   tcp      1
#
# [461043 rows x 4 columns]

# %%
features = list(df.columns)
features.remove('label')

# %%
for col,typ in dict(df.dtypes).items():
  if typ == 'category':
    df[col] = df[col].cat.codes.astype(int)
  else:
    vs = list(df[col].unique())
    # should not happen in the full dataset, otherwise would be removed in 1st step of preproc
    if (len(vs) == 1) and (np.isnan(vs[0])):
      print('error',col,'const column with NaN. Replacing with 0')
      df[col] = 0
    elif (len(vs) == 2) and (np.isnan(vs[0]) or np.isnan(vs[1])):
      val = vs[1] if np.isnan(vs[0]) else vs[0]
      val = -val if val != 0 else 1
      df[col] = df[col].fillna(value=val)
    else:
      df[col] = df[col].fillna(df[col].mean())

# %%
model = tfdf.keras.RandomForestModel()
model.compile()
# Out:
# Use /tmp/tmp0zm0s9f6 as temporary training directory

# %%
X_train, X_test, Y_train, Y_test = train_test_split(df.drop('label',axis=1).values, 
                                                    df['label'].values, 
                                                    test_size=0.3,
                                                    random_state=42)

# %%
history = model.fit(X_train,
                    Y_train,
                    verbose = 1)
# Out:
# Reading training dataset...
# Training dataset read in 0:00:09.574356. Found 322730 examples.
# Training model...
# Model trained in 0:01:34.254571
# Compiling model...
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f6cffacbc20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f6cffacbc20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f6cffacbc20> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model compiled.

# %%
predict = model.predict(X_test, verbose=1)
# Out:
# 4323/4323 [==============================] - 9s 2ms/step

# %%
tp,tn,fp,fn = 0,0,0,0
predictn = predict.flatten().round().tolist()
len(predictn)
for i in range(len(predictn)):
  if predictn[i]==1 and Y_test[i]==1:
    tp+=1
  elif predictn[i]==0 and Y_test[i]==0:
    tn+=1
  elif predictn[i]==0 and Y_test[i]==1:
    fp+=1
  elif predictn[i]==1 and Y_test[i]==0:
    fn+=1
    
print(tp,tn,fp,fn)
classification_report(Y_test, predictn, output_dict=True)
# Out:
# 45006 88183 3335 1789
# {'0': {'f1-score': 0.9717670395063088,
#   'precision': 0.9635590812736292,
#   'recall': 0.98011603610012,
#   'support': 89972},
#  '1': {'f1-score': 0.9461402623612513,
#   'precision': 0.9617694198098088,
#   'recall': 0.9310109430917854,
#   'support': 48341},
#  'accuracy': 0.9629535907687636,
#  'macro avg': {'f1-score': 0.95895365093378,
#   'precision': 0.962664250541719,
#   'recall': 0.9555634895959527,
#   'support': 138313},
#  'weighted avg': {'f1-score': 0.9628103685211575,
#   'precision': 0.9629335867443908,
#   'recall': 0.9629535907687636,
#   'support': 138313}}

# %%
print(model.summary())
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (3):
# 	data:0.0
# 	data:0.1
# 	data:0.2
#
# No weights
#
# Variable Importance: MEAN_MIN_DEPTH:
#     1.  "__LABEL" 12.693432 ################
#     2. "data:0.0"  2.447369 ###
#     3. "data:0.1"  1.000000 #
#     4. "data:0.2"  0.000000
#
# Variable Importance: NUM_AS_ROOT:
#     1. "data:0.2" 300.000000
#
# Variable Importance: NUM_NODES:
#     1. "data:0.0" 95062.000000 ################
#     2. "data:0.1" 18480.000000 ###
#     3. "data:0.2" 600.000000
#
# Variable Importance: SUM_SCORE:
#     1. "data:0.1" 27789575.734710 ################
#     2. "data:0.2" 14515839.564453 ####
#     3. "data:0.0" 9772106.999418
#
#
#
# Winner take all: true
# Out-of-bag evaluation: accuracy:0.963781 logloss:1.1033
# Number of trees: 300
# Total number of nodes: 228584
#
# Number of nodes by tree:
# Count: 300 Average: 761.947 StdDev: 79.828
# Min: 571 Max: 1009 Ignored: 0
# ----------------------------------------------
# [  571,  592)  3   1.00%   1.00% #
# [  592,  614)  4   1.33%   2.33% #
# [  614,  636)  5   1.67%   4.00% #
# [  636,  658) 16   5.33%   9.33% ####
# [  658,  680) 18   6.00%  15.33% #####
# [  680,  702) 20   6.67%  22.00% #####
# [  702,  724) 30  10.00%  32.00% ########
# [  724,  746) 38  12.67%  44.67% ##########
# [  746,  768) 35  11.67%  56.33% #########
# [  768,  790) 26   8.67%  65.00% #######
# [  790,  812) 34  11.33%  76.33% #########
# [  812,  834) 21   7.00%  83.33% ######
# [  834,  856) 15   5.00%  88.33% ####
# [  856,  878) 11   3.67%  92.00% ###
# [  878,  900)  6   2.00%  94.00% ##
# [  900,  922)  6   2.00%  96.00% ##
# [  922,  944)  5   1.67%  97.67% #
# [  944,  966)  5   1.67%  99.33% #
# [  966,  988)  0   0.00%  99.33%
# [  988, 1009]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 114442 Average: 12.7089 StdDev: 2.94695
# Min: 3 Max: 15 Ignored: 0
# ----------------------------------------------
# [  3,  4)   283   0.25%   0.25%
# [  4,  5)  1505   1.32%   1.56%
# [  5,  6)  2040   1.78%   3.34%
# [  6,  7)  2453   2.14%   5.49%
# [  7,  8)  3801   3.32%   8.81% #
# [  8,  9)  4131   3.61%  12.42% #
# [  9, 10)  4644   4.06%  16.48% #
# [ 10, 11)  4585   4.01%  20.48% #
# [ 11, 12)  6787   5.93%  26.41% #
# [ 12, 13)  7785   6.80%  33.22% ##
# [ 13, 14) 11879  10.38%  43.60% ##
# [ 14, 15) 15399  13.46%  57.05% ###
# [ 15, 15] 49150  42.95% 100.00% ##########
#
# Number of training obs by leaf:
# Count: 114442 Average: 846.009 StdDev: 3334.83
# Min: 5 Max: 49329 Ignored: 0
# ----------------------------------------------
# [     5,  2471) 106226  92.82%  92.82% ##########
# [  2471,  4937)   3499   3.06%  95.88%
# [  4937,  7403)    968   0.85%  96.72%
# [  7403,  9870)    755   0.66%  97.38%
# [  9870, 12336)   1208   1.06%  98.44%
# [ 12336, 14802)    290   0.25%  98.69%
# [ 14802, 17268)     69   0.06%  98.75%
# [ 17268, 19735)     23   0.02%  98.77%
# [ 19735, 22201)    345   0.30%  99.07%
# [ 22201, 24667)    616   0.54%  99.61%
# [ 24667, 27133)     52   0.05%  99.66%
# [ 27133, 29600)     28   0.02%  99.68%
# [ 29600, 32066)    159   0.14%  99.82%
# [ 32066, 34532)     88   0.08%  99.90%
# [ 34532, 36998)      8   0.01%  99.91%
# [ 36998, 39465)     70   0.06%  99.97%
# [ 39465, 41931)      5   0.00%  99.97%
# [ 41931, 44397)     13   0.01%  99.98%
# [ 44397, 46863)     16   0.01% 100.00%
# [ 46863, 49329]      4   0.00% 100.00%
#
# Attribute in nodes:
# 	95062 : data:0.0 [NUMERICAL]
# 	18480 : data:0.1 [NUMERICAL]
# 	600 : data:0.2 [NUMERICAL]
#
# Attribute in nodes with depth <= 0:
# 	300 : data:0.2 [NUMERICAL]
#
# Attribute in nodes with depth <= 1:
# 	600 : data:0.1 [NUMERICAL]
# 	300 : data:0.2 [NUMERICAL]
#
# Attribute in nodes with depth <= 2:
# 	900 : data:0.0 [NUMERICAL]
# 	600 : data:0.2 [NUMERICAL]
# 	600 : data:0.1 [NUMERICAL]
#
# Attribute in nodes with depth <= 3:
# 	1914 : data:0.0 [NUMERICAL]
# 	1703 : data:0.1 [NUMERICAL]
# 	600 : data:0.2 [NUMERICAL]
#
# Attribute in nodes with depth <= 5:
# 	4909 : data:0.1 [NUMERICAL]
# 	4855 : data:0.0 [NUMERICAL]
# 	600 : data:0.2 [NUMERICAL]
#
# Condition type in nodes:
# 	114142 : HigherCondition
# Condition type in nodes with depth <= 0:
# 	300 : HigherCondition
# Condition type in nodes with depth <= 1:
# 	900 : HigherCondition
# Condition type in nodes with depth <= 2:
# 	2100 : HigherCondition
# Condition type in nodes with depth <= 3:
# 	4217 : HigherCondition
# Condition type in nodes with depth <= 5:
# 	10364 : HigherCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.963914 logloss:1.30068
# 	trees: 11, Out-of-bag evaluation: accuracy:0.963749 logloss:1.26519
# 	trees: 21, Out-of-bag evaluation: accuracy:0.96374 logloss:1.24273
# 	trees: 31, Out-of-bag evaluation: accuracy:0.963768 logloss:1.23171
# 	trees: 41, Out-of-bag evaluation: accuracy:0.963759 logloss:1.22268
# 	trees: 51, Out-of-bag evaluation: accuracy:0.963772 logloss:1.21385
# 	trees: 61, Out-of-bag evaluation: accuracy:0.963772 logloss:1.20792
# 	trees: 71, Out-of-bag evaluation: accuracy:0.963765 logloss:1.2015
# 	trees: 81, Out-of-bag evaluation: accuracy:0.963775 logloss:1.19612
# 	trees: 91, Out-of-bag evaluation: accuracy:0.963784 logloss:1.19113
# 	trees: 101, Out-of-bag evaluation: accuracy:0.963793 logloss:1.18615
# 	trees: 111, Out-of-bag evaluation: accuracy:0.963793 logloss:1.18128
# 	trees: 121, Out-of-bag evaluation: accuracy:0.963781 logloss:1.17488
# 	trees: 131, Out-of-bag evaluation: accuracy:0.963778 logloss:1.16892
# 	trees: 141, Out-of-bag evaluation: accuracy:0.963784 logloss:1.16438
# 	trees: 151, Out-of-bag evaluation: accuracy:0.963784 logloss:1.16021
# 	trees: 161, Out-of-bag evaluation: accuracy:0.963784 logloss:1.15553
# 	trees: 171, Out-of-bag evaluation: accuracy:0.963778 logloss:1.15147
# 	trees: 181, Out-of-bag evaluation: accuracy:0.963781 logloss:1.14802
# 	trees: 191, Out-of-bag evaluation: accuracy:0.963784 logloss:1.14168
# 	trees: 201, Out-of-bag evaluation: accuracy:0.963793 logloss:1.13821
# 	trees: 211, Out-of-bag evaluation: accuracy:0.963775 logloss:1.13543
# 	trees: 221, Out-of-bag evaluation: accuracy:0.963793 logloss:1.13271
# 	trees: 231, Out-of-bag evaluation: accuracy:0.96379 logloss:1.12925
# 	trees: 241, Out-of-bag evaluation: accuracy:0.963793 logloss:1.12565
# 	trees: 251, Out-of-bag evaluation: accuracy:0.963793 logloss:1.12152
# 	trees: 261, Out-of-bag evaluation: accuracy:0.963793 logloss:1.11777
# 	trees: 271, Out-of-bag evaluation: accuracy:0.963787 logloss:1.11396
# 	trees: 281, Out-of-bag evaluation: accuracy:0.963784 logloss:1.11005
# 	trees: 291, Out-of-bag evaluation: accuracy:0.963772 logloss:1.10604
# 	trees: 300, Out-of-bag evaluation: accuracy:0.963781 logloss:1.1033
#
# None

# %%
model.save('/content/drive/Shareddrives/datasci/ton_iot/RF.tf')
with open('/content/drive/Shareddrives/datasci/ton_iot/result/RF.csv','w') as infile:
  txt = ''
  for pred in predictn:
    txt += str(int(pred))+','
  txt = txt[:-1]
  txt += '\n'
  infile.write(txt)
# Out:
# WARNING:absl:Found untraced functions such as call_get_leaves while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/RF.tf/assets
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/RF.tf/assets
