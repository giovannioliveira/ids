# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow -U tensorflow_decision_forests > /dev/null

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow_decision_forests as tfdf
from sklearn.metrics import classification_report
base_dir = '/content/drive/Shareddrives/datasci/ton_iot/result/'

# %%
X = []
Y = None
with open(base_dir+'ALL.csv','r') as infile:
  for line in infile:
    pred = line.rstrip().split(',')
    if pred[0] == 'LABEL':
      Y = np.array(pred[1:], dtype='int8').transpose()
    else:
      X.append(pred[1:])
X = np.array(X, dtype='int8').transpose()

# %%
model = tfdf.keras.RandomForestModel()
model.compile()
# Out:
# Use /tmp/tmp5j9_dfb3 as temporary training directory

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, 
                                                    Y, 
                                                    test_size=0.3,
                                                    random_state=345)

# %%
history = model.fit(X_train,
                    Y_train,
                    verbose = 1)
# Out:
# Reading training dataset...
# Training dataset read in 0:00:14.256950. Found 96819 examples.
# Training model...
# Model trained in 0:00:23.873543
# Compiling model...
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7fb6abcdbb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7fb6abcdbb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7fb6abcdbb90> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model compiled.

# %%
predict = model.predict(X_test, verbose=1)
# Out:
# 1297/1297 [==============================] - 4s 3ms/step

# %%
tp,tn,fp,fn = 0,0,0,0
predictn = predict.flatten().round().tolist()
len(predictn)
for i in range(len(predictn)):
  if predictn[i]==1 and Y_test[i]==1:
    tp+=1
  elif predictn[i]==0 and Y_test[i]==0:
    tn+=1
  elif predictn[i]==0 and Y_test[i]==1:
    fp+=1
  elif predictn[i]==1 and Y_test[i]==0:
    fn+=1
    
print(tp,tn,fp,fn)
classification_report(Y_test, predictn, output_dict=True)
# Out:
# 14483 26879 61 71
# {'0': {'f1-score': 0.997550565967712,
#   'precision': 0.9977357089829251,
#   'recall': 0.9973654916512059,
#   'support': 26950},
#  '1': {'f1-score': 0.9954636057460995,
#   'precision': 0.9951216160505703,
#   'recall': 0.9958058305830583,
#   'support': 14544},
#  'accuracy': 0.9968188171783873,
#  'macro avg': {'f1-score': 0.9965070858569057,
#   'precision': 0.9964286625167477,
#   'recall': 0.9965856611171321,
#   'support': 41494},
#  'weighted avg': {'f1-score': 0.996819068655736,
#   'precision': 0.9968194471713822,
#   'recall': 0.9968188171783873,
#   'support': 41494}}

# %%
print(model.summary())
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (10):
# 	data:0.0
# 	data:0.1
# 	data:0.2
# 	data:0.3
# 	data:0.4
# 	data:0.5
# 	data:0.6
# 	data:0.7
# 	data:0.8
# 	data:0.9
#
# No weights
#
# Variable Importance: MEAN_MIN_DEPTH:
#     1.  "__LABEL"  5.980567 ################
#     2. "data:0.5"  5.553792 ##############
#     3. "data:0.4"  5.371770 #############
#     4. "data:0.2"  5.143183 #############
#     5. "data:0.9"  4.301769 ##########
#     6. "data:0.3"  4.147099 #########
#     7. "data:0.1"  3.824646 ########
#     8. "data:0.6"  3.552448 #######
#     9. "data:0.0"  3.151321 ######
#    10. "data:0.7"  1.903347 ##
#    11. "data:0.8"  1.305864
#
# Variable Importance: NUM_AS_ROOT:
#     1. "data:0.8" 154.000000 ################
#     2. "data:0.7" 93.000000 #########
#     3. "data:0.0" 28.000000 ##
#     4. "data:0.3" 20.000000 #
#     5. "data:0.6"  4.000000
#     6. "data:0.5"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "data:0.9" 2802.000000 ################
#     2. "data:0.6" 2149.000000 ###########
#     3. "data:0.1" 1728.000000 ########
#     4. "data:0.4" 1663.000000 #######
#     5. "data:0.7" 1269.000000 ####
#     6. "data:0.8" 1015.000000 ###
#     7. "data:0.3" 859.000000 ##
#     8. "data:0.2" 834.000000 #
#     9. "data:0.0" 760.000000 #
#    10. "data:0.5" 576.000000
#
# Variable Importance: SUM_SCORE:
#     1. "data:0.8" 9289963.992567 ################
#     2. "data:0.7" 5392795.875046 #########
#     3. "data:0.0" 1741313.080910 ##
#     4. "data:0.3" 1134377.601480 #
#     5. "data:0.6" 481553.022694
#     6. "data:0.1" 198457.564218
#     7. "data:0.5" 70190.588065
#     8. "data:0.9" 61623.922913
#     9. "data:0.2" 56918.865675
#    10. "data:0.4" 7931.645661
#
#
#
# Winner take all: true
# Out-of-bag evaluation: accuracy:0.996447 logloss:0.103384
# Number of trees: 300
# Total number of nodes: 27610
#
# Number of nodes by tree:
# Count: 300 Average: 92.0333 StdDev: 4.78179
# Min: 79 Max: 105 Ignored: 0
# ----------------------------------------------
# [  79,  80)  5   1.67%   1.67% #
# [  80,  81)  0   0.00%   1.67%
# [  81,  83)  5   1.67%   3.33% #
# [  83,  84)  9   3.00%   6.33% ##
# [  84,  85)  0   0.00%   6.33%
# [  85,  87) 13   4.33%  10.67% ##
# [  87,  88) 28   9.33%  20.00% #####
# [  88,  89)  0   0.00%  20.00%
# [  89,  91) 29   9.67%  29.67% #####
# [  91,  92) 48  16.00%  45.67% ########
# [  92,  93)  0   0.00%  45.67%
# [  93,  95) 50  16.67%  62.33% #########
# [  95,  96) 57  19.00%  81.33% ##########
# [  96,  97)  0   0.00%  81.33%
# [  97,  99) 32  10.67%  92.00% ######
# [  99, 100) 15   5.00%  97.00% ###
# [ 100, 101)  0   0.00%  97.00%
# [ 101, 103)  5   1.67%  98.67% #
# [ 103, 104)  3   1.00%  99.67% #
# [ 104, 105]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 13955 Average: 5.98431 StdDev: 1.16332
# Min: 2 Max: 10 Ignored: 0
# ----------------------------------------------
# [  2,  3)    1   0.01%   0.01%
# [  3,  4)  123   0.88%   0.89%
# [  4,  5) 1204   8.63%   9.52% ##
# [  5,  6) 3169  22.71%  32.23% ######
# [  6,  7) 5348  38.32%  70.55% ##########
# [  7,  8) 2857  20.47%  91.02% #####
# [  8,  9)  921   6.60%  97.62% ##
# [  9, 10)  296   2.12%  99.74% #
# [ 10, 10]   36   0.26% 100.00%
#
# Number of training obs by leaf:
# Count: 13955 Average: 2081.38 StdDev: 5842.04
# Min: 5 Max: 30691 Ignored: 0
# ----------------------------------------------
# [     5,  1539) 11955  85.67%  85.67% ##########
# [  1539,  3073)   505   3.62%  89.29%
# [  3073,  4608)     0   0.00%  89.29%
# [  4608,  6142)     0   0.00%  89.29%
# [  6142,  7676)    33   0.24%  89.52%
# [  7676,  9211)   262   1.88%  91.40%
# [  9211, 10745)     0   0.00%  91.40%
# [ 10745, 12279)   294   2.11%  93.51%
# [ 12279, 13814)     6   0.04%  93.55%
# [ 13814, 15348)     0   0.00%  93.55%
# [ 15348, 16882)     0   0.00%  93.55%
# [ 16882, 18417)   206   1.48%  95.03%
# [ 18417, 19951)     3   0.02%  95.05%
# [ 19951, 21485)   297   2.13%  97.18%
# [ 21485, 23020)    89   0.64%  97.81%
# [ 23020, 24554)     0   0.00%  97.81%
# [ 24554, 26088)     0   0.00%  97.81%
# [ 26088, 27623)   262   1.88%  99.69%
# [ 27623, 29157)    38   0.27%  99.96%
# [ 29157, 30691]     5   0.04% 100.00%
#
# Attribute in nodes:
# 	2802 : data:0.9 [CATEGORICAL]
# 	2149 : data:0.6 [CATEGORICAL]
# 	1728 : data:0.1 [CATEGORICAL]
# 	1663 : data:0.4 [CATEGORICAL]
# 	1269 : data:0.7 [CATEGORICAL]
# 	1015 : data:0.8 [CATEGORICAL]
# 	859 : data:0.3 [CATEGORICAL]
# 	834 : data:0.2 [CATEGORICAL]
# 	760 : data:0.0 [CATEGORICAL]
# 	576 : data:0.5 [CATEGORICAL]
#
# Attribute in nodes with depth <= 0:
# 	154 : data:0.8 [CATEGORICAL]
# 	93 : data:0.7 [CATEGORICAL]
# 	28 : data:0.0 [CATEGORICAL]
# 	20 : data:0.3 [CATEGORICAL]
# 	4 : data:0.6 [CATEGORICAL]
# 	1 : data:0.5 [CATEGORICAL]
#
# Attribute in nodes with depth <= 1:
# 	265 : data:0.8 [CATEGORICAL]
# 	223 : data:0.0 [CATEGORICAL]
# 	158 : data:0.7 [CATEGORICAL]
# 	121 : data:0.6 [CATEGORICAL]
# 	120 : data:0.3 [CATEGORICAL]
# 	5 : data:0.4 [CATEGORICAL]
# 	4 : data:0.9 [CATEGORICAL]
# 	2 : data:0.5 [CATEGORICAL]
# 	2 : data:0.1 [CATEGORICAL]
#
# Attribute in nodes with depth <= 2:
# 	465 : data:0.7 [CATEGORICAL]
# 	392 : data:0.8 [CATEGORICAL]
# 	313 : data:0.0 [CATEGORICAL]
# 	253 : data:0.1 [CATEGORICAL]
# 	247 : data:0.6 [CATEGORICAL]
# 	190 : data:0.3 [CATEGORICAL]
# 	112 : data:0.9 [CATEGORICAL]
# 	59 : data:0.2 [CATEGORICAL]
# 	44 : data:0.5 [CATEGORICAL]
# 	24 : data:0.4 [CATEGORICAL]
#
# Attribute in nodes with depth <= 3:
# 	846 : data:0.7 [CATEGORICAL]
# 	733 : data:0.9 [CATEGORICAL]
# 	718 : data:0.1 [CATEGORICAL]
# 	583 : data:0.6 [CATEGORICAL]
# 	548 : data:0.8 [CATEGORICAL]
# 	440 : data:0.0 [CATEGORICAL]
# 	250 : data:0.3 [CATEGORICAL]
# 	138 : data:0.2 [CATEGORICAL]
# 	63 : data:0.4 [CATEGORICAL]
# 	55 : data:0.5 [CATEGORICAL]
#
# Attribute in nodes with depth <= 5:
# 	2482 : data:0.9 [CATEGORICAL]
# 	1918 : data:0.6 [CATEGORICAL]
# 	1666 : data:0.1 [CATEGORICAL]
# 	1232 : data:0.7 [CATEGORICAL]
# 	1071 : data:0.4 [CATEGORICAL]
# 	798 : data:0.8 [CATEGORICAL]
# 	702 : data:0.0 [CATEGORICAL]
# 	536 : data:0.3 [CATEGORICAL]
# 	514 : data:0.2 [CATEGORICAL]
# 	324 : data:0.5 [CATEGORICAL]
#
# Condition type in nodes:
# 	13655 : ContainsBitmapCondition
# Condition type in nodes with depth <= 0:
# 	300 : ContainsBitmapCondition
# Condition type in nodes with depth <= 1:
# 	900 : ContainsBitmapCondition
# Condition type in nodes with depth <= 2:
# 	2099 : ContainsBitmapCondition
# Condition type in nodes with depth <= 3:
# 	4374 : ContainsBitmapCondition
# Condition type in nodes with depth <= 5:
# 	11243 : ContainsBitmapCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.996332 logloss:0.132222
# 	trees: 11, Out-of-bag evaluation: accuracy:0.996467 logloss:0.115676
# 	trees: 21, Out-of-bag evaluation: accuracy:0.996426 logloss:0.115571
# 	trees: 31, Out-of-bag evaluation: accuracy:0.996437 logloss:0.108929
# 	trees: 41, Out-of-bag evaluation: accuracy:0.996447 logloss:0.106853
# 	trees: 51, Out-of-bag evaluation: accuracy:0.996447 logloss:0.104706
# 	trees: 61, Out-of-bag evaluation: accuracy:0.996447 logloss:0.104701
# 	trees: 71, Out-of-bag evaluation: accuracy:0.996447 logloss:0.104378
# 	trees: 81, Out-of-bag evaluation: accuracy:0.996447 logloss:0.104099
# 	trees: 91, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103728
# 	trees: 101, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103731
# 	trees: 111, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103773
# 	trees: 121, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103816
# 	trees: 131, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103778
# 	trees: 141, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103755
# 	trees: 151, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103397
# 	trees: 161, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103395
# 	trees: 171, Out-of-bag evaluation: accuracy:0.996447 logloss:0.10339
# 	trees: 181, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103382
# 	trees: 191, Out-of-bag evaluation: accuracy:0.996447 logloss:0.10339
# 	trees: 201, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103383
# 	trees: 211, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103387
# 	trees: 221, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103388
# 	trees: 231, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103391
# 	trees: 241, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103386
# 	trees: 251, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103367
# 	trees: 261, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103366
# 	trees: 271, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103371
# 	trees: 281, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103377
# 	trees: 291, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103384
# 	trees: 300, Out-of-bag evaluation: accuracy:0.996447 logloss:0.103384
#
# None

# %%
model.save('/content/drive/Shareddrives/datasci/ton_iot/result/RF.tf')
# Out:
# WARNING:absl:Found untraced functions such as call_get_leaves while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/result/RF.tf/assets
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/result/RF.tf/assets
