# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow -U tensorflow_decision_forests > /dev/null

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow_decision_forests as tfdf
from sklearn.metrics import classification_report
base_dir = '/content/drive/Shareddrives/datasci/ton_iot/result/'

# %%
X = []
Y = None
with open(base_dir+'ALL.csv','r') as infile:
  for line in infile:
    pred = line.rstrip().split(',')
    if pred[0] == 'LABEL':
      Y = np.array(pred[1:], dtype='int8').transpose()
    else:
      X.append(pred[1:])
X = np.array(X, dtype='int8').transpose()

# %%
model = tfdf.keras.RandomForestModel()
model.compile()
# Out:
# Use /tmp/tmpeh9wsl96 as temporary training directory

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, 
                                                    Y, 
                                                    test_size=0.3,
                                                    random_state=42)

# %%
history = model.fit(X_train,
                    Y_train,
                    verbose = 1)
# Out:
# Reading training dataset...
# Training dataset read in 0:00:10.517956. Found 96819 examples.
# Training model...
# Model trained in 0:00:14.206209
# Compiling model...
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7fe0e0316200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7fe0e0316200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7fe0e0316200> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model compiled.

# %%
predict = model.predict(X_test, verbose=1)
# Out:
# 1297/1297 [==============================] - 3s 2ms/step

# %%
tp,tn,fp,fn = 0,0,0,0
predictn = predict.flatten().round().tolist()
len(predictn)
for i in range(len(predictn)):
  if predictn[i]==1 and Y_test[i]==1:
    tp+=1
  elif predictn[i]==0 and Y_test[i]==0:
    tn+=1
  elif predictn[i]==0 and Y_test[i]==1:
    fp+=1
  elif predictn[i]==1 and Y_test[i]==0:
    fn+=1
    
print(tp,tn,fp,fn)
classification_report(Y_test, predictn, output_dict=True)
# Out:
# 14330 26994 58 112
# {'0': {'f1-score': 0.9968610362273348,
#   'precision': 0.997855981073488,
#   'recall': 0.9958680734892643,
#   'support': 27106},
#  '1': {'f1-score': 0.9941033645508152,
#   'precision': 0.9922448414347044,
#   'recall': 0.99596886294134,
#   'support': 14388},
#  'accuracy': 0.9959030221236805,
#  'macro avg': {'f1-score': 0.995482200389075,
#   'precision': 0.9950504112540962,
#   'recall': 0.9959184682153022,
#   'support': 41494},
#  'weighted avg': {'f1-score': 0.9959048165309508,
#   'precision': 0.9959103244213741,
#   'recall': 0.9959030221236805,
#   'support': 41494}}

# %%
print(model.summary())
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (10):
# 	data:0.0
# 	data:0.1
# 	data:0.2
# 	data:0.3
# 	data:0.4
# 	data:0.5
# 	data:0.6
# 	data:0.7
# 	data:0.8
# 	data:0.9
#
# No weights
#
# Variable Importance: MEAN_MIN_DEPTH:
#     1.  "__LABEL"  5.887009 ################
#     2. "data:0.5"  5.410294 ##############
#     3. "data:0.4"  5.345655 ##############
#     4. "data:0.2"  5.253701 #############
#     5. "data:0.9"  4.161249 ##########
#     6. "data:0.1"  3.864149 #########
#     7. "data:0.3"  3.838486 ########
#     8. "data:0.0"  3.777748 ########
#     9. "data:0.6"  3.227783 ######
#    10. "data:0.7"  1.884471 ##
#    11. "data:0.8"  1.240762
#
# Variable Importance: NUM_AS_ROOT:
#     1. "data:0.8" 154.000000 ################
#     2. "data:0.7" 93.000000 #########
#     3. "data:0.3" 30.000000 ###
#     4. "data:0.0" 18.000000 #
#     5. "data:0.6"  4.000000
#     6. "data:0.4"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "data:0.9" 2661.000000 ################
#     2. "data:0.6" 1911.000000 ##########
#     3. "data:0.1" 1859.000000 #########
#     4. "data:0.4" 1651.000000 ########
#     5. "data:0.7" 1310.000000 #####
#     6. "data:0.8" 952.000000 ###
#     7. "data:0.3" 783.000000 #
#     8. "data:0.2" 746.000000 #
#     9. "data:0.0" 726.000000 #
#    10. "data:0.5" 549.000000
#
# Variable Importance: SUM_SCORE:
#     1. "data:0.8" 9393360.419514 ################
#     2. "data:0.7" 5414232.559873 #########
#     3. "data:0.3" 1581509.199168 ##
#     4. "data:0.0" 1165786.031849 #
#     5. "data:0.6" 555620.891258
#     6. "data:0.1" 180605.749606
#     7. "data:0.9" 71763.622191
#     8. "data:0.2" 55650.025162
#     9. "data:0.4" 46231.747514
#    10. "data:0.5" 33598.105889
#
#
#
# Winner take all: true
# Out-of-bag evaluation: accuracy:0.996757 logloss:0.0933548
# Number of trees: 300
# Total number of nodes: 26596
#
# Number of nodes by tree:
# Count: 300 Average: 88.6533 StdDev: 4.66903
# Min: 75 Max: 101 Ignored: 0
# ----------------------------------------------
# [  75,  76)  2   0.67%   0.67%
# [  76,  77)  0   0.00%   0.67%
# [  77,  79)  0   0.00%   0.67%
# [  79,  80)  4   1.33%   2.00% #
# [  80,  81)  0   0.00%   2.00%
# [  81,  83) 14   4.67%   6.67% ##
# [  83,  84) 28   9.33%  16.00% #####
# [  84,  85)  0   0.00%  16.00%
# [  85,  87) 40  13.33%  29.33% #######
# [  87,  88) 47  15.67%  45.00% ########
# [  88,  89)  0   0.00%  45.00%
# [  89,  91) 58  19.33%  64.33% ##########
# [  91,  92) 36  12.00%  76.33% ######
# [  92,  93)  0   0.00%  76.33%
# [  93,  95) 30  10.00%  86.33% #####
# [  95,  96) 22   7.33%  93.67% ####
# [  96,  97)  0   0.00%  93.67%
# [  97,  99) 11   3.67%  97.33% ##
# [  99, 100)  5   1.67%  99.00% #
# [ 100, 101]  3   1.00% 100.00% #
#
# Depth by leafs:
# Count: 13448 Average: 5.89069 StdDev: 1.09013
# Min: 3 Max: 10 Ignored: 0
# ----------------------------------------------
# [  3,  4)  138   1.03%   1.03%
# [  4,  5) 1143   8.50%   9.53% ##
# [  5,  6) 3410  25.36%  34.88% #######
# [  6,  7) 5121  38.08%  72.96% ##########
# [  7,  8) 2753  20.47%  93.43% #####
# [  8,  9)  776   5.77%  99.20% ##
# [  9, 10)   93   0.69%  99.90%
# [ 10, 10]   14   0.10% 100.00%
#
# Number of training obs by leaf:
# Count: 13448 Average: 2159.85 StdDev: 5977.6
# Min: 5 Max: 45512 Ignored: 0
# ----------------------------------------------
# [     5,  2280) 11730  87.22%  87.22% ##########
# [  2280,  4555)   232   1.73%  88.95%
# [  4555,  6831)     0   0.00%  88.95%
# [  6831,  9106)   294   2.19%  91.14%
# [  9106, 11382)     4   0.03%  91.17%
# [ 11382, 13657)   300   2.23%  93.40%
# [ 13657, 15932)     0   0.00%  93.40%
# [ 15932, 18208)   233   1.73%  95.13%
# [ 18208, 20483)    44   0.33%  95.46%
# [ 20483, 22759)   309   2.30%  97.75%
# [ 22759, 25034)     0   0.00%  97.75%
# [ 25034, 27309)    80   0.59%  98.35%
# [ 27309, 29585)   208   1.55%  99.90%
# [ 29585, 31860)     2   0.01%  99.91%
# [ 31860, 34136)     0   0.00%  99.91%
# [ 34136, 36411)     0   0.00%  99.91%
# [ 36411, 38686)     0   0.00%  99.91%
# [ 38686, 40962)     0   0.00%  99.91%
# [ 40962, 43237)     0   0.00%  99.91%
# [ 43237, 45512]    12   0.09% 100.00%
#
# Attribute in nodes:
# 	2661 : data:0.9 [CATEGORICAL]
# 	1911 : data:0.6 [CATEGORICAL]
# 	1859 : data:0.1 [CATEGORICAL]
# 	1651 : data:0.4 [CATEGORICAL]
# 	1310 : data:0.7 [CATEGORICAL]
# 	952 : data:0.8 [CATEGORICAL]
# 	783 : data:0.3 [CATEGORICAL]
# 	746 : data:0.2 [CATEGORICAL]
# 	726 : data:0.0 [CATEGORICAL]
# 	549 : data:0.5 [CATEGORICAL]
#
# Attribute in nodes with depth <= 0:
# 	154 : data:0.8 [CATEGORICAL]
# 	93 : data:0.7 [CATEGORICAL]
# 	30 : data:0.3 [CATEGORICAL]
# 	18 : data:0.0 [CATEGORICAL]
# 	4 : data:0.6 [CATEGORICAL]
# 	1 : data:0.4 [CATEGORICAL]
#
# Attribute in nodes with depth <= 1:
# 	267 : data:0.8 [CATEGORICAL]
# 	199 : data:0.7 [CATEGORICAL]
# 	154 : data:0.6 [CATEGORICAL]
# 	140 : data:0.0 [CATEGORICAL]
# 	125 : data:0.3 [CATEGORICAL]
# 	7 : data:0.9 [CATEGORICAL]
# 	5 : data:0.4 [CATEGORICAL]
# 	2 : data:0.5 [CATEGORICAL]
# 	1 : data:0.1 [CATEGORICAL]
#
# Attribute in nodes with depth <= 2:
# 	439 : data:0.7 [CATEGORICAL]
# 	398 : data:0.8 [CATEGORICAL]
# 	296 : data:0.6 [CATEGORICAL]
# 	251 : data:0.0 [CATEGORICAL]
# 	239 : data:0.3 [CATEGORICAL]
# 	235 : data:0.1 [CATEGORICAL]
# 	104 : data:0.9 [CATEGORICAL]
# 	60 : data:0.2 [CATEGORICAL]
# 	51 : data:0.5 [CATEGORICAL]
# 	27 : data:0.4 [CATEGORICAL]
#
# Attribute in nodes with depth <= 3:
# 	815 : data:0.9 [CATEGORICAL]
# 	728 : data:0.1 [CATEGORICAL]
# 	721 : data:0.7 [CATEGORICAL]
# 	605 : data:0.6 [CATEGORICAL]
# 	541 : data:0.8 [CATEGORICAL]
# 	387 : data:0.0 [CATEGORICAL]
# 	319 : data:0.3 [CATEGORICAL]
# 	102 : data:0.2 [CATEGORICAL]
# 	85 : data:0.4 [CATEGORICAL]
# 	59 : data:0.5 [CATEGORICAL]
#
# Attribute in nodes with depth <= 5:
# 	2377 : data:0.9 [CATEGORICAL]
# 	1799 : data:0.1 [CATEGORICAL]
# 	1781 : data:0.6 [CATEGORICAL]
# 	1277 : data:0.7 [CATEGORICAL]
# 	1045 : data:0.4 [CATEGORICAL]
# 	833 : data:0.8 [CATEGORICAL]
# 	677 : data:0.0 [CATEGORICAL]
# 	492 : data:0.3 [CATEGORICAL]
# 	452 : data:0.2 [CATEGORICAL]
# 	362 : data:0.5 [CATEGORICAL]
#
# Condition type in nodes:
# 	13148 : ContainsBitmapCondition
# Condition type in nodes with depth <= 0:
# 	300 : ContainsBitmapCondition
# Condition type in nodes with depth <= 1:
# 	900 : ContainsBitmapCondition
# Condition type in nodes with depth <= 2:
# 	2100 : ContainsBitmapCondition
# Condition type in nodes with depth <= 3:
# 	4362 : ContainsBitmapCondition
# Condition type in nodes with depth <= 5:
# 	11095 : ContainsBitmapCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.996445 logloss:0.128153
# 	trees: 11, Out-of-bag evaluation: accuracy:0.996622 logloss:0.106006
# 	trees: 21, Out-of-bag evaluation: accuracy:0.996684 logloss:0.0969871
# 	trees: 31, Out-of-bag evaluation: accuracy:0.996612 logloss:0.0947753
# 	trees: 41, Out-of-bag evaluation: accuracy:0.996705 logloss:0.0944157
# 	trees: 51, Out-of-bag evaluation: accuracy:0.996746 logloss:0.0944617
# 	trees: 61, Out-of-bag evaluation: accuracy:0.996736 logloss:0.0941106
# 	trees: 71, Out-of-bag evaluation: accuracy:0.996746 logloss:0.0940717
# 	trees: 81, Out-of-bag evaluation: accuracy:0.996757 logloss:0.0940438
# 	trees: 91, Out-of-bag evaluation: accuracy:0.996767 logloss:0.094069
# 	trees: 101, Out-of-bag evaluation: accuracy:0.996757 logloss:0.0936903
# 	trees: 111, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933423
# 	trees: 121, Out-of-bag evaluation: accuracy:0.996777 logloss:0.0933473
# 	trees: 131, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933525
# 	trees: 141, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933447
# 	trees: 151, Out-of-bag evaluation: accuracy:0.996767 logloss:0.093355
# 	trees: 161, Out-of-bag evaluation: accuracy:0.996757 logloss:0.0933664
# 	trees: 171, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933619
# 	trees: 181, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933678
# 	trees: 191, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933733
# 	trees: 201, Out-of-bag evaluation: accuracy:0.996757 logloss:0.0933745
# 	trees: 211, Out-of-bag evaluation: accuracy:0.996746 logloss:0.0933684
# 	trees: 221, Out-of-bag evaluation: accuracy:0.996757 logloss:0.0933703
# 	trees: 231, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933729
# 	trees: 241, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933751
# 	trees: 251, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933772
# 	trees: 261, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933727
# 	trees: 271, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933693
# 	trees: 281, Out-of-bag evaluation: accuracy:0.996767 logloss:0.0933737
# 	trees: 291, Out-of-bag evaluation: accuracy:0.996757 logloss:0.0933659
# 	trees: 300, Out-of-bag evaluation: accuracy:0.996757 logloss:0.0933548
#
# None

# %%
model.save('/content/drive/Shareddrives/datasci/ton_iot/result/RF.tf')
# Out:
# WARNING:absl:Found untraced functions such as call_get_leaves while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/result/RF.tf/assets
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/result/RF.tf/assets
