# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow -U tensorflow_decision_forests > /dev/null

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow_decision_forests as tfdf
from sklearn.metrics import classification_report
base_dir = '/content/drive/Shareddrives/datasci/ton_iot/result/'

# %%
X = []
Y = None
with open(base_dir+'ALL.csv','r') as infile:
  for line in infile:
    pred = line.rstrip().split(',')
    if pred[0] == 'LABEL':
      Y = np.array(pred[1:], dtype='int8').transpose()
    else:
      X.append(pred[1:])
X = np.array(X, dtype='int8').transpose()

# %%
model = tfdf.keras.RandomForestModel()
model.compile()
# Out:
# Use /tmp/tmpjg3zhg74 as temporary training directory

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, 
                                                    Y, 
                                                    test_size=0.3,
                                                    random_state=564)

# %%
history = model.fit(X_train,
                    Y_train,
                    verbose = 1)
# Out:
# Reading training dataset...
# Training dataset read in 0:00:10.177067. Found 96819 examples.
# Training model...
# Model trained in 0:00:14.454302
# Compiling model...
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f3a468080e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f3a468080e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f3a468080e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model compiled.

# %%
predict = model.predict(X_test, verbose=1)
# Out:
# 1297/1297 [==============================] - 3s 2ms/step

# %%
tp,tn,fp,fn = 0,0,0,0
predictn = predict.flatten().round().tolist()
len(predictn)
for i in range(len(predictn)):
  if predictn[i]==1 and Y_test[i]==1:
    tp+=1
  elif predictn[i]==0 and Y_test[i]==0:
    tn+=1
  elif predictn[i]==0 and Y_test[i]==1:
    fp+=1
  elif predictn[i]==1 and Y_test[i]==0:
    fn+=1
    
print(tp,tn,fp,fn)
classification_report(Y_test, predictn, output_dict=True)
# Out:
# 14387 26946 80 81
# {'0': {'f1-score': 0.9970214419181174,
#   'precision': 0.9970398875157256,
#   'recall': 0.997002997002997,
#   'support': 27027},
#  '1': {'f1-score': 0.994435804389148,
#   'precision': 0.9944014376555156,
#   'recall': 0.9944701734983065,
#   'support': 14467},
#  'accuracy': 0.9961199209524269,
#  'macro avg': {'f1-score': 0.9957286231536326,
#   'precision': 0.9957206625856205,
#   'recall': 0.9957365852506517,
#   'support': 41494},
#  'weighted avg': {'f1-score': 0.9961199521091908,
#   'precision': 0.9961199845387252,
#   'recall': 0.9961199209524269,
#   'support': 41494}}

# %%
print(model.summary())
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (10):
# 	data:0.0
# 	data:0.1
# 	data:0.2
# 	data:0.3
# 	data:0.4
# 	data:0.5
# 	data:0.6
# 	data:0.7
# 	data:0.8
# 	data:0.9
#
# No weights
#
# Variable Importance: MEAN_MIN_DEPTH:
#     1.  "__LABEL"  6.020037 ################
#     2. "data:0.5"  5.404031 #############
#     3. "data:0.4"  5.369756 #############
#     4. "data:0.2"  5.276731 #############
#     5. "data:0.9"  4.199943 #########
#     6. "data:0.1"  4.079643 #########
#     7. "data:0.3"  4.026211 #########
#     8. "data:0.0"  3.591572 #######
#     9. "data:0.6"  3.255972 ######
#    10. "data:0.7"  1.931494 ##
#    11. "data:0.8"  1.276878
#
# Variable Importance: NUM_AS_ROOT:
#     1. "data:0.8" 154.000000 ################
#     2. "data:0.7" 93.000000 #########
#     3. "data:0.3" 31.000000 ###
#     4. "data:0.0" 17.000000 #
#     5. "data:0.6"  4.000000
#     6. "data:0.4"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "data:0.9" 2881.000000 ################
#     2. "data:0.4" 2083.000000 ##########
#     3. "data:0.6" 1909.000000 #########
#     4. "data:0.1" 1795.000000 ########
#     5. "data:0.7" 1320.000000 #####
#     6. "data:0.8" 993.000000 ##
#     7. "data:0.2" 979.000000 ##
#     8. "data:0.0" 802.000000 #
#     9. "data:0.3" 699.000000
#    10. "data:0.5" 609.000000
#
# Variable Importance: SUM_SCORE:
#     1. "data:0.8" 9323180.884144 ################
#     2. "data:0.7" 5410513.548369 #########
#     3. "data:0.3" 1624886.677810 ##
#     4. "data:0.0" 1180489.374047 #
#     5. "data:0.6" 537009.104711
#     6. "data:0.1" 192341.033165
#     7. "data:0.9" 72403.906803
#     8. "data:0.2" 52913.067036
#     9. "data:0.4" 48035.146275
#    10. "data:0.5" 42822.595345
#
#
#
# Winner take all: true
# Out-of-bag evaluation: accuracy:0.996736 logloss:0.092506
# Number of trees: 300
# Total number of nodes: 28440
#
# Number of nodes by tree:
# Count: 300 Average: 94.8 StdDev: 5.96098
# Min: 79 Max: 109 Ignored: 0
# ----------------------------------------------
# [  79,  80)  1   0.33%   0.33%
# [  80,  82)  7   2.33%   2.67% ##
# [  82,  83)  0   0.00%   2.67%
# [  83,  85)  5   1.67%   4.33% #
# [  85,  86) 12   4.00%   8.33% ###
# [  86,  88) 14   4.67%  13.00% ####
# [  88,  89)  0   0.00%  13.00%
# [  89,  91) 21   7.00%  20.00% #####
# [  91,  92) 33  11.00%  31.00% ########
# [  92,  94) 38  12.67%  43.67% ##########
# [  94,  96) 40  13.33%  57.00% ##########
# [  96,  97)  0   0.00%  57.00%
# [  97,  99) 39  13.00%  70.00% ##########
# [  99, 100) 31  10.33%  80.33% ########
# [ 100, 102) 23   7.67%  88.00% ######
# [ 102, 103)  0   0.00%  88.00%
# [ 103, 105) 17   5.67%  93.67% ####
# [ 105, 106) 14   4.67%  98.33% ####
# [ 106, 108)  3   1.00%  99.33% #
# [ 108, 109]  2   0.67% 100.00% #
#
# Depth by leafs:
# Count: 14370 Average: 6.0263 StdDev: 1.14842
# Min: 2 Max: 10 Ignored: 0
# ----------------------------------------------
# [  2,  3)    1   0.01%   0.01%
# [  3,  4)  128   0.89%   0.90%
# [  4,  5) 1088   7.57%   8.47% ##
# [  5,  6) 3375  23.49%  31.96% #######
# [  6,  7) 5096  35.46%  67.42% ##########
# [  7,  8) 3283  22.85%  90.26% ######
# [  8,  9) 1167   8.12%  98.39% ##
# [  9, 10)  228   1.59%  99.97%
# [ 10, 10]    4   0.03% 100.00%
#
# Number of training obs by leaf:
# Count: 14370 Average: 2021.27 StdDev: 5769.47
# Min: 5 Max: 45376 Ignored: 0
# ----------------------------------------------
# [     5,  2273) 12834  89.31%  89.31% ##########
# [  2273,  4542)    47   0.33%  89.64%
# [  4542,  6810)     0   0.00%  89.64%
# [  6810,  9079)   293   2.04%  91.68%
# [  9079, 11348)     4   0.03%  91.70%
# [ 11348, 13616)   300   2.09%  93.79%
# [ 13616, 15885)     0   0.00%  93.79%
# [ 15885, 18153)   252   1.75%  95.55%
# [ 18153, 20422)    37   0.26%  95.80%
# [ 20422, 22691)   300   2.09%  97.89%
# [ 22691, 24959)     0   0.00%  97.89%
# [ 24959, 27228)    35   0.24%  98.14%
# [ 27228, 29496)   257   1.79%  99.92%
# [ 29496, 31765)     3   0.02%  99.94%
# [ 31765, 34034)     0   0.00%  99.94%
# [ 34034, 36302)     0   0.00%  99.94%
# [ 36302, 38571)     0   0.00%  99.94%
# [ 38571, 40839)     0   0.00%  99.94%
# [ 40839, 43108)     0   0.00%  99.94%
# [ 43108, 45376]     8   0.06% 100.00%
#
# Attribute in nodes:
# 	2881 : data:0.9 [CATEGORICAL]
# 	2083 : data:0.4 [CATEGORICAL]
# 	1909 : data:0.6 [CATEGORICAL]
# 	1795 : data:0.1 [CATEGORICAL]
# 	1320 : data:0.7 [CATEGORICAL]
# 	993 : data:0.8 [CATEGORICAL]
# 	979 : data:0.2 [CATEGORICAL]
# 	802 : data:0.0 [CATEGORICAL]
# 	699 : data:0.3 [CATEGORICAL]
# 	609 : data:0.5 [CATEGORICAL]
#
# Attribute in nodes with depth <= 0:
# 	154 : data:0.8 [CATEGORICAL]
# 	93 : data:0.7 [CATEGORICAL]
# 	31 : data:0.3 [CATEGORICAL]
# 	17 : data:0.0 [CATEGORICAL]
# 	4 : data:0.6 [CATEGORICAL]
# 	1 : data:0.4 [CATEGORICAL]
#
# Attribute in nodes with depth <= 1:
# 	260 : data:0.8 [CATEGORICAL]
# 	183 : data:0.0 [CATEGORICAL]
# 	176 : data:0.7 [CATEGORICAL]
# 	142 : data:0.6 [CATEGORICAL]
# 	121 : data:0.3 [CATEGORICAL]
# 	11 : data:0.9 [CATEGORICAL]
# 	4 : data:0.4 [CATEGORICAL]
# 	2 : data:0.5 [CATEGORICAL]
# 	1 : data:0.1 [CATEGORICAL]
#
# Attribute in nodes with depth <= 2:
# 	411 : data:0.7 [CATEGORICAL]
# 	381 : data:0.8 [CATEGORICAL]
# 	339 : data:0.6 [CATEGORICAL]
# 	302 : data:0.0 [CATEGORICAL]
# 	232 : data:0.1 [CATEGORICAL]
# 	209 : data:0.3 [CATEGORICAL]
# 	88 : data:0.9 [CATEGORICAL]
# 	65 : data:0.5 [CATEGORICAL]
# 	50 : data:0.2 [CATEGORICAL]
# 	22 : data:0.4 [CATEGORICAL]
#
# Attribute in nodes with depth <= 3:
# 	772 : data:0.7 [CATEGORICAL]
# 	720 : data:0.6 [CATEGORICAL]
# 	705 : data:0.9 [CATEGORICAL]
# 	662 : data:0.1 [CATEGORICAL]
# 	480 : data:0.8 [CATEGORICAL]
# 	463 : data:0.0 [CATEGORICAL]
# 	278 : data:0.3 [CATEGORICAL]
# 	119 : data:0.2 [CATEGORICAL]
# 	105 : data:0.5 [CATEGORICAL]
# 	65 : data:0.4 [CATEGORICAL]
#
# Attribute in nodes with depth <= 5:
# 	2592 : data:0.9 [CATEGORICAL]
# 	1664 : data:0.6 [CATEGORICAL]
# 	1569 : data:0.1 [CATEGORICAL]
# 	1288 : data:0.7 [CATEGORICAL]
# 	1198 : data:0.4 [CATEGORICAL]
# 	842 : data:0.8 [CATEGORICAL]
# 	713 : data:0.0 [CATEGORICAL]
# 	583 : data:0.2 [CATEGORICAL]
# 	475 : data:0.5 [CATEGORICAL]
# 	426 : data:0.3 [CATEGORICAL]
#
# Condition type in nodes:
# 	14070 : ContainsBitmapCondition
# Condition type in nodes with depth <= 0:
# 	300 : ContainsBitmapCondition
# Condition type in nodes with depth <= 1:
# 	900 : ContainsBitmapCondition
# Condition type in nodes with depth <= 2:
# 	2099 : ContainsBitmapCondition
# Condition type in nodes with depth <= 3:
# 	4369 : ContainsBitmapCondition
# Condition type in nodes with depth <= 5:
# 	11350 : ContainsBitmapCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.996557 logloss:0.124085
# 	trees: 11, Out-of-bag evaluation: accuracy:0.996602 logloss:0.105016
# 	trees: 21, Out-of-bag evaluation: accuracy:0.996591 logloss:0.0987026
# 	trees: 31, Out-of-bag evaluation: accuracy:0.996633 logloss:0.0969064
# 	trees: 41, Out-of-bag evaluation: accuracy:0.996643 logloss:0.0965517
# 	trees: 51, Out-of-bag evaluation: accuracy:0.996654 logloss:0.0958561
# 	trees: 61, Out-of-bag evaluation: accuracy:0.996654 logloss:0.0954796
# 	trees: 71, Out-of-bag evaluation: accuracy:0.996695 logloss:0.0955078
# 	trees: 81, Out-of-bag evaluation: accuracy:0.996705 logloss:0.0948364
# 	trees: 91, Out-of-bag evaluation: accuracy:0.996695 logloss:0.0944875
# 	trees: 101, Out-of-bag evaluation: accuracy:0.996695 logloss:0.0944894
# 	trees: 111, Out-of-bag evaluation: accuracy:0.996654 logloss:0.0944795
# 	trees: 121, Out-of-bag evaluation: accuracy:0.996643 logloss:0.0934762
# 	trees: 131, Out-of-bag evaluation: accuracy:0.996674 logloss:0.0934732
# 	trees: 141, Out-of-bag evaluation: accuracy:0.996685 logloss:0.0934814
# 	trees: 151, Out-of-bag evaluation: accuracy:0.996695 logloss:0.0931582
# 	trees: 161, Out-of-bag evaluation: accuracy:0.996726 logloss:0.0928024
# 	trees: 171, Out-of-bag evaluation: accuracy:0.996736 logloss:0.0928117
# 	trees: 181, Out-of-bag evaluation: accuracy:0.996736 logloss:0.0924879
# 	trees: 191, Out-of-bag evaluation: accuracy:0.996736 logloss:0.0924877
# 	trees: 201, Out-of-bag evaluation: accuracy:0.996736 logloss:0.0924915
# 	trees: 211, Out-of-bag evaluation: accuracy:0.996726 logloss:0.0924953
# 	trees: 221, Out-of-bag evaluation: accuracy:0.996726 logloss:0.0924927
# 	trees: 231, Out-of-bag evaluation: accuracy:0.996726 logloss:0.0925059
# 	trees: 241, Out-of-bag evaluation: accuracy:0.996736 logloss:0.0925073
# 	trees: 251, Out-of-bag evaluation: accuracy:0.996736 logloss:0.0925163
# 	trees: 261, Out-of-bag evaluation: accuracy:0.996746 logloss:0.0925118
# 	trees: 271, Out-of-bag evaluation: accuracy:0.996736 logloss:0.0925087
# 	trees: 281, Out-of-bag evaluation: accuracy:0.996736 logloss:0.0925059
# 	trees: 291, Out-of-bag evaluation: accuracy:0.996736 logloss:0.0925059
# 	trees: 300, Out-of-bag evaluation: accuracy:0.996736 logloss:0.092506
#
# None

# %%
model.save('/content/drive/Shareddrives/datasci/ton_iot/result/RF.tf')
# Out:
# WARNING:absl:Found untraced functions such as call_get_leaves while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/result/RF.tf/assets
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/result/RF.tf/assets
