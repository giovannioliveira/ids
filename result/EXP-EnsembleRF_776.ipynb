# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow -U tensorflow_decision_forests > /dev/null

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow_decision_forests as tfdf
from sklearn.metrics import classification_report
base_dir = '/content/drive/Shareddrives/datasci/ton_iot/result/'

# %%
X = []
Y = None
with open(base_dir+'ALL.csv','r') as infile:
  for line in infile:
    pred = line.rstrip().split(',')
    if pred[0] == 'LABEL':
      Y = np.array(pred[1:], dtype='int8').transpose()
    else:
      X.append(pred[1:])
X = np.array(X, dtype='int8').transpose()

# %%
model = tfdf.keras.RandomForestModel()
model.compile()
# Out:
# Use /tmp/tmpgrhsa2hs as temporary training directory

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, 
                                                    Y, 
                                                    test_size=0.3,
                                                    random_state=776)

# %%
history = model.fit(X_train,
                    Y_train,
                    verbose = 1)
# Out:
# Reading training dataset...
# Training dataset read in 0:00:08.310941. Found 96819 examples.
# Training model...
# Model trained in 0:00:12.512629
# Compiling model...
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f8dc9e189e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f8dc9e189e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f8dc9e189e0> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model compiled.

# %%
predict = model.predict(X_test, verbose=1)
# Out:
# 1297/1297 [==============================] - 2s 2ms/step

# %%
tp,tn,fp,fn = 0,0,0,0
predictn = predict.flatten().round().tolist()
len(predictn)
for i in range(len(predictn)):
  if predictn[i]==1 and Y_test[i]==1:
    tp+=1
  elif predictn[i]==0 and Y_test[i]==0:
    tn+=1
  elif predictn[i]==0 and Y_test[i]==1:
    fp+=1
  elif predictn[i]==1 and Y_test[i]==0:
    fn+=1
    
print(tp,tn,fp,fn)
classification_report(Y_test, predictn, output_dict=True)
# Out:
# 14334 27014 80 66
# {'0': {'f1-score': 0.9973049802488279,
#   'precision': 0.9970473167490957,
#   'recall': 0.997562776957164,
#   'support': 27080},
#  '1': {'f1-score': 0.9949330186714791,
#   'precision': 0.9954166666666666,
#   'recall': 0.9944498404329124,
#   'support': 14414},
#  'accuracy': 0.9964814190003374,
#  'macro avg': {'f1-score': 0.9961189994601535,
#   'precision': 0.9962319917078812,
#   'recall': 0.9960063086950381,
#   'support': 41494},
#  'weighted avg': {'f1-score': 0.9964810188525801,
#   'precision': 0.9964808688219704,
#   'recall': 0.9964814190003374,
#   'support': 41494}}

# %%
print(model.summary())
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (10):
# 	data:0.0
# 	data:0.1
# 	data:0.2
# 	data:0.3
# 	data:0.4
# 	data:0.5
# 	data:0.6
# 	data:0.7
# 	data:0.8
# 	data:0.9
#
# No weights
#
# Variable Importance: MEAN_MIN_DEPTH:
#     1.  "__LABEL"  6.067132 ################
#     2. "data:0.5"  5.443844 #############
#     3. "data:0.4"  5.361529 #############
#     4. "data:0.2"  5.329617 #############
#     5. "data:0.9"  4.165144 #########
#     6. "data:0.1"  4.144503 #########
#     7. "data:0.3"  3.994173 #########
#     8. "data:0.0"  3.633630 #######
#     9. "data:0.6"  3.189856 ######
#    10. "data:0.7"  2.014730 ##
#    11. "data:0.8"  1.272748
#
# Variable Importance: NUM_AS_ROOT:
#     1. "data:0.8" 154.000000 ################
#     2. "data:0.7" 93.000000 #########
#     3. "data:0.3" 28.000000 ##
#     4. "data:0.0" 20.000000 #
#     5. "data:0.6"  4.000000
#     6. "data:0.4"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "data:0.9" 2729.000000 ################
#     2. "data:0.4" 2098.000000 ##########
#     3. "data:0.6" 1963.000000 #########
#     4. "data:0.1" 1828.000000 ########
#     5. "data:0.7" 1354.000000 #####
#     6. "data:0.8" 985.000000 ##
#     7. "data:0.2" 983.000000 ##
#     8. "data:0.0" 844.000000
#     9. "data:0.3" 814.000000
#    10. "data:0.5" 720.000000
#
# Variable Importance: SUM_SCORE:
#     1. "data:0.8" 9326358.364510 ################
#     2. "data:0.7" 5403423.278147 #########
#     3. "data:0.3" 1498367.043439 ##
#     4. "data:0.0" 1310883.222727 ##
#     5. "data:0.6" 549553.237103
#     6. "data:0.1" 188237.922346
#     7. "data:0.9" 66066.654401
#     8. "data:0.4" 49823.615826
#     9. "data:0.2" 47306.681917
#    10. "data:0.5" 36321.300147
#
#
#
# Winner take all: true
# Out-of-bag evaluation: accuracy:0.996602 logloss:0.102923
# Number of trees: 300
# Total number of nodes: 28936
#
# Number of nodes by tree:
# Count: 300 Average: 96.4533 StdDev: 6.14447
# Min: 81 Max: 115 Ignored: 0
# ----------------------------------------------
# [  81,  82)  4   1.33%   1.33% #
# [  82,  84)  2   0.67%   2.00%
# [  84,  86)  4   1.33%   3.33% #
# [  86,  88) 10   3.33%   6.67% ##
# [  88,  89)  0   0.00%   6.67%
# [  89,  91) 23   7.67%  14.33% ######
# [  91,  93) 31  10.33%  24.67% ########
# [  93,  95) 32  10.67%  35.33% ########
# [  95,  96) 41  13.67%  49.00% ##########
# [  96,  98) 37  12.33%  61.33% #########
# [  98, 100) 33  11.00%  72.33% ########
# [ 100, 102) 26   8.67%  81.00% ######
# [ 102, 103)  0   0.00%  81.00%
# [ 103, 105) 22   7.33%  88.33% #####
# [ 105, 107) 15   5.00%  93.33% ####
# [ 107, 109) 11   3.67%  97.00% ###
# [ 109, 110)  5   1.67%  98.67% #
# [ 110, 112)  2   0.67%  99.33%
# [ 112, 114)  0   0.00%  99.33%
# [ 114, 115]  2   0.67% 100.00%
#
# Depth by leafs:
# Count: 14618 Average: 6.0732 StdDev: 1.16904
# Min: 3 Max: 10 Ignored: 0
# ----------------------------------------------
# [  3,  4)  142   0.97%   0.97%
# [  4,  5) 1135   7.76%   8.74% ##
# [  5,  6) 3152  21.56%  30.30% ######
# [  6,  7) 5111  34.96%  65.26% ##########
# [  7,  8) 3474  23.77%  89.03% #######
# [  8,  9) 1376   9.41%  98.44% ###
# [  9, 10)  220   1.50%  99.95%
# [ 10, 10]    8   0.05% 100.00%
#
# Number of training obs by leaf:
# Count: 14618 Average: 1986.98 StdDev: 5730.78
# Min: 5 Max: 44890 Ignored: 0
# ----------------------------------------------
# [     5,  2249) 13045  89.24%  89.24% ##########
# [  2249,  4493)    86   0.59%  89.83%
# [  4493,  6737)     0   0.00%  89.83%
# [  6737,  8982)   286   1.96%  91.78%
# [  8982, 11226)    12   0.08%  91.87%
# [ 11226, 13470)   297   2.03%  93.90%
# [ 13470, 15715)     3   0.02%  93.92%
# [ 15715, 17959)   269   1.84%  95.76%
# [ 17959, 20203)    10   0.07%  95.83%
# [ 20203, 22448)   308   2.11%  97.93%
# [ 22448, 24692)     0   0.00%  97.93%
# [ 24692, 26936)     0   0.00%  97.93%
# [ 26936, 29180)   289   1.98%  99.91%
# [ 29180, 31425)     2   0.01%  99.92%
# [ 31425, 33669)     0   0.00%  99.92%
# [ 33669, 35913)     0   0.00%  99.92%
# [ 35913, 38158)     0   0.00%  99.92%
# [ 38158, 40402)     0   0.00%  99.92%
# [ 40402, 42646)     0   0.00%  99.92%
# [ 42646, 44890]    11   0.08% 100.00%
#
# Attribute in nodes:
# 	2729 : data:0.9 [CATEGORICAL]
# 	2098 : data:0.4 [CATEGORICAL]
# 	1963 : data:0.6 [CATEGORICAL]
# 	1828 : data:0.1 [CATEGORICAL]
# 	1354 : data:0.7 [CATEGORICAL]
# 	985 : data:0.8 [CATEGORICAL]
# 	983 : data:0.2 [CATEGORICAL]
# 	844 : data:0.0 [CATEGORICAL]
# 	814 : data:0.3 [CATEGORICAL]
# 	720 : data:0.5 [CATEGORICAL]
#
# Attribute in nodes with depth <= 0:
# 	154 : data:0.8 [CATEGORICAL]
# 	93 : data:0.7 [CATEGORICAL]
# 	28 : data:0.3 [CATEGORICAL]
# 	20 : data:0.0 [CATEGORICAL]
# 	4 : data:0.6 [CATEGORICAL]
# 	1 : data:0.4 [CATEGORICAL]
#
# Attribute in nodes with depth <= 1:
# 	257 : data:0.8 [CATEGORICAL]
# 	182 : data:0.0 [CATEGORICAL]
# 	151 : data:0.6 [CATEGORICAL]
# 	149 : data:0.3 [CATEGORICAL]
# 	148 : data:0.7 [CATEGORICAL]
# 	6 : data:0.4 [CATEGORICAL]
# 	5 : data:0.9 [CATEGORICAL]
# 	1 : data:0.5 [CATEGORICAL]
# 	1 : data:0.1 [CATEGORICAL]
#
# Attribute in nodes with depth <= 2:
# 	449 : data:0.7 [CATEGORICAL]
# 	361 : data:0.8 [CATEGORICAL]
# 	319 : data:0.6 [CATEGORICAL]
# 	256 : data:0.1 [CATEGORICAL]
# 	241 : data:0.0 [CATEGORICAL]
# 	201 : data:0.3 [CATEGORICAL]
# 	139 : data:0.9 [CATEGORICAL]
# 	51 : data:0.5 [CATEGORICAL]
# 	51 : data:0.2 [CATEGORICAL]
# 	32 : data:0.4 [CATEGORICAL]
#
# Attribute in nodes with depth <= 3:
# 	808 : data:0.7 [CATEGORICAL]
# 	734 : data:0.9 [CATEGORICAL]
# 	672 : data:0.6 [CATEGORICAL]
# 	663 : data:0.1 [CATEGORICAL]
# 	485 : data:0.8 [CATEGORICAL]
# 	399 : data:0.0 [CATEGORICAL]
# 	269 : data:0.3 [CATEGORICAL]
# 	123 : data:0.4 [CATEGORICAL]
# 	109 : data:0.2 [CATEGORICAL]
# 	96 : data:0.5 [CATEGORICAL]
#
# Attribute in nodes with depth <= 5:
# 	2439 : data:0.9 [CATEGORICAL]
# 	1788 : data:0.6 [CATEGORICAL]
# 	1505 : data:0.1 [CATEGORICAL]
# 	1278 : data:0.7 [CATEGORICAL]
# 	1184 : data:0.4 [CATEGORICAL]
# 	891 : data:0.8 [CATEGORICAL]
# 	727 : data:0.0 [CATEGORICAL]
# 	554 : data:0.2 [CATEGORICAL]
# 	513 : data:0.3 [CATEGORICAL]
# 	470 : data:0.5 [CATEGORICAL]
#
# Condition type in nodes:
# 	14318 : ContainsBitmapCondition
# Condition type in nodes with depth <= 0:
# 	300 : ContainsBitmapCondition
# Condition type in nodes with depth <= 1:
# 	900 : ContainsBitmapCondition
# Condition type in nodes with depth <= 2:
# 	2100 : ContainsBitmapCondition
# Condition type in nodes with depth <= 3:
# 	4358 : ContainsBitmapCondition
# Condition type in nodes with depth <= 5:
# 	11349 : ContainsBitmapCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.996642 logloss:0.121034
# 	trees: 11, Out-of-bag evaluation: accuracy:0.996529 logloss:0.113393
# 	trees: 21, Out-of-bag evaluation: accuracy:0.99655 logloss:0.110374
# 	trees: 31, Out-of-bag evaluation: accuracy:0.996561 logloss:0.106274
# 	trees: 41, Out-of-bag evaluation: accuracy:0.996592 logloss:0.104904
# 	trees: 51, Out-of-bag evaluation: accuracy:0.996592 logloss:0.103846
# 	trees: 61, Out-of-bag evaluation: accuracy:0.996592 logloss:0.103513
# 	trees: 71, Out-of-bag evaluation: accuracy:0.996592 logloss:0.103505
# 	trees: 81, Out-of-bag evaluation: accuracy:0.996592 logloss:0.102793
# 	trees: 91, Out-of-bag evaluation: accuracy:0.996592 logloss:0.102842
# 	trees: 101, Out-of-bag evaluation: accuracy:0.996592 logloss:0.102885
# 	trees: 111, Out-of-bag evaluation: accuracy:0.996592 logloss:0.102924
# 	trees: 121, Out-of-bag evaluation: accuracy:0.996592 logloss:0.102955
# 	trees: 131, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102972
# 	trees: 141, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102996
# 	trees: 151, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102955
# 	trees: 161, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102941
# 	trees: 171, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102914
# 	trees: 181, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102911
# 	trees: 191, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102903
# 	trees: 201, Out-of-bag evaluation: accuracy:0.996602 logloss:0.10291
# 	trees: 211, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102929
# 	trees: 221, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102932
# 	trees: 231, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102949
# 	trees: 241, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102964
# 	trees: 251, Out-of-bag evaluation: accuracy:0.996602 logloss:0.10296
# 	trees: 261, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102928
# 	trees: 271, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102913
# 	trees: 281, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102906
# 	trees: 291, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102913
# 	trees: 300, Out-of-bag evaluation: accuracy:0.996602 logloss:0.102923
#
# None

# %%
model.save('/content/drive/Shareddrives/datasci/ton_iot/result/RF.tf')
# Out:
# WARNING:absl:Found untraced functions such as call_get_leaves while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/result/RF.tf/assets
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/result/RF.tf/assets
