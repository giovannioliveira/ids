# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pip install tensorflow -U tensorflow_decision_forests > /dev/null

# %%
import numpy as np
from sklearn.model_selection import train_test_split
import tensorflow_decision_forests as tfdf
from sklearn.metrics import classification_report
base_dir = '/content/drive/Shareddrives/datasci/ton_iot/result/'

# %%
X = []
Y = None
with open(base_dir+'ALL.csv','r') as infile:
  for line in infile:
    pred = line.rstrip().split(',')
    if pred[0] == 'LABEL':
      Y = np.array(pred[1:], dtype='int8').transpose()
    else:
      X.append(pred[1:])
X = np.array(X, dtype='int8').transpose()

# %%
model = tfdf.keras.RandomForestModel()
model.compile()
# Out:
# Use /tmp/tmpg6fj2vfs as temporary training directory

# %%
X_train, X_test, Y_train, Y_test = train_test_split(X, 
                                                    Y, 
                                                    test_size=0.3,
                                                    random_state=897)

# %%
history = model.fit(X_train,
                    Y_train,
                    verbose = 1)
# Out:
# Reading training dataset...
# Training dataset read in 0:00:08.483336. Found 96819 examples.
# Training model...
# Model trained in 0:00:14.313223
# Compiling model...
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f71fd239950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING:tensorflow:AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f71fd239950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# WARNING: AutoGraph could not transform <function simple_ml_inference_op_with_handle at 0x7f71fd239950> and will run it as-is.
# Please report this to the TensorFlow team. When filing the bug, set the verbosity to 10 (on Linux, `export AUTOGRAPH_VERBOSITY=10`) and attach the full output.
# Cause: could not get source code
# To silence this warning, decorate the function with @tf.autograph.experimental.do_not_convert
# Model compiled.

# %%
predict = model.predict(X_test, verbose=1)
# Out:
# 1297/1297 [==============================] - 2s 2ms/step

# %%
tp,tn,fp,fn = 0,0,0,0
predictn = predict.flatten().round().tolist()
len(predictn)
for i in range(len(predictn)):
  if predictn[i]==1 and Y_test[i]==1:
    tp+=1
  elif predictn[i]==0 and Y_test[i]==0:
    tn+=1
  elif predictn[i]==0 and Y_test[i]==1:
    fp+=1
  elif predictn[i]==1 and Y_test[i]==0:
    fn+=1
    
print(tp,tn,fp,fn)
classification_report(Y_test, predictn, output_dict=True)
# Out:
# 14382 26954 65 93
# {'0': {'f1-score': 0.9970776458402693,
#   'precision': 0.9975942855027943,
#   'recall': 0.9965615410211853,
#   'support': 27047},
#  '1': {'f1-score': 0.9945370306341194,
#   'precision': 0.9935751295336788,
#   'recall': 0.9955007960130131,
#   'support': 14447},
#  'accuracy': 0.996192220562009,
#  'macro avg': {'f1-score': 0.9958073382371944,
#   'precision': 0.9955847075182365,
#   'recall': 0.9960311685170993,
#   'support': 41494},
#  'weighted avg': {'f1-score': 0.9961930777609508,
#   'precision': 0.9961949326738114,
#   'recall': 0.996192220562009,
#   'support': 41494}}

# %%
print(model.summary())
# Out:
# Model: "random_forest_model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
# =================================================================
# Total params: 1
# Trainable params: 0
# Non-trainable params: 1
# _________________________________________________________________
# Type: "RANDOM_FOREST"
# Task: CLASSIFICATION
# Label: "__LABEL"
#
# Input Features (10):
# 	data:0.0
# 	data:0.1
# 	data:0.2
# 	data:0.3
# 	data:0.4
# 	data:0.5
# 	data:0.6
# 	data:0.7
# 	data:0.8
# 	data:0.9
#
# No weights
#
# Variable Importance: MEAN_MIN_DEPTH:
#     1.  "__LABEL"  6.057472 ################
#     2. "data:0.4"  5.419962 #############
#     3. "data:0.5"  5.315075 #############
#     4. "data:0.2"  5.293447 #############
#     5. "data:0.9"  4.206630 #########
#     6. "data:0.1"  4.150414 #########
#     7. "data:0.3"  4.014258 #########
#     8. "data:0.0"  3.619435 #######
#     9. "data:0.6"  3.321925 ######
#    10. "data:0.7"  1.921618 ##
#    11. "data:0.8"  1.258089
#
# Variable Importance: NUM_AS_ROOT:
#     1. "data:0.8" 154.000000 ################
#     2. "data:0.7" 93.000000 #########
#     3. "data:0.3" 29.000000 ##
#     4. "data:0.0" 19.000000 #
#     5. "data:0.6"  4.000000
#     6. "data:0.5"  1.000000
#
# Variable Importance: NUM_NODES:
#     1. "data:0.9" 2910.000000 ################
#     2. "data:0.4" 2196.000000 ##########
#     3. "data:0.6" 2021.000000 #########
#     4. "data:0.1" 1867.000000 ########
#     5. "data:0.7" 1311.000000 ####
#     6. "data:0.8" 976.000000 ##
#     7. "data:0.2" 971.000000 ##
#     8. "data:0.3" 753.000000
#     9. "data:0.0" 729.000000
#    10. "data:0.5" 688.000000
#
# Variable Importance: SUM_SCORE:
#     1. "data:0.8" 9366250.740840 ################
#     2. "data:0.7" 5394440.524966 #########
#     3. "data:0.3" 1526252.376259 ##
#     4. "data:0.0" 1262222.018197 ##
#     5. "data:0.6" 528196.346935
#     6. "data:0.1" 184028.667695
#     7. "data:0.5" 89845.357654
#     8. "data:0.9" 66050.697188
#     9. "data:0.2" 53113.117443
#    10. "data:0.4" 7552.928796
#
#
#
# Winner take all: true
# Out-of-bag evaluation: accuracy:0.996633 logloss:0.095791
# Number of trees: 300
# Total number of nodes: 29144
#
# Number of nodes by tree:
# Count: 300 Average: 97.1467 StdDev: 5.86104
# Min: 81 Max: 115 Ignored: 0
# ----------------------------------------------
# [  81,  82)  1   0.33%   0.33%
# [  82,  84)  1   0.33%   0.67%
# [  84,  86)  8   2.67%   3.33% ##
# [  86,  88) 15   5.00%   8.33% ###
# [  88,  89)  0   0.00%   8.33%
# [  89,  91)  6   2.00%  10.33% #
# [  91,  93) 27   9.00%  19.33% ######
# [  93,  95) 28   9.33%  28.67% ######
# [  95,  96) 41  13.67%  42.33% ########
# [  96,  98) 34  11.33%  53.67% #######
# [  98, 100) 35  11.67%  65.33% #######
# [ 100, 102) 49  16.33%  81.67% ##########
# [ 102, 103)  0   0.00%  81.67%
# [ 103, 105) 28   9.33%  91.00% ######
# [ 105, 107)  8   2.67%  93.67% ##
# [ 107, 109)  9   3.00%  96.67% ##
# [ 109, 110)  6   2.00%  98.67% #
# [ 110, 112)  1   0.33%  99.00%
# [ 112, 114)  2   0.67%  99.67%
# [ 114, 115]  1   0.33% 100.00%
#
# Depth by leafs:
# Count: 14722 Average: 6.06331 StdDev: 1.16622
# Min: 2 Max: 10 Ignored: 0
# ----------------------------------------------
# [  2,  3)    1   0.01%   0.01%
# [  3,  4)   74   0.50%   0.51%
# [  4,  5) 1161   7.89%   8.40% ##
# [  5,  6) 3351  22.76%  31.16% ######
# [  6,  7) 5238  35.58%  66.74% ##########
# [  7,  8) 3298  22.40%  89.14% ######
# [  8,  9) 1282   8.71%  97.85% ##
# [  9, 10)  299   2.03%  99.88% #
# [ 10, 10]   18   0.12% 100.00%
#
# Number of training obs by leaf:
# Count: 14722 Average: 1972.95 StdDev: 5719.41
# Min: 5 Max: 45341 Ignored: 0
# ----------------------------------------------
# [     5,  2271) 13174  89.49%  89.49% ##########
# [  2271,  4538)    63   0.43%  89.91%
# [  4538,  6805)     0   0.00%  89.91%
# [  6805,  9072)   295   2.00%  91.92%
# [  9072, 11339)     1   0.01%  91.92%
# [ 11339, 13606)   300   2.04%  93.96%
# [ 13606, 15872)     0   0.00%  93.96%
# [ 15872, 18139)   269   1.83%  95.79%
# [ 18139, 20406)    11   0.07%  95.86%
# [ 20406, 22673)   305   2.07%  97.94%
# [ 22673, 24940)     0   0.00%  97.94%
# [ 24940, 27207)    79   0.54%  98.47%
# [ 27207, 29474)   211   1.43%  99.90%
# [ 29474, 31740)     3   0.02%  99.93%
# [ 31740, 34007)     0   0.00%  99.93%
# [ 34007, 36274)     0   0.00%  99.93%
# [ 36274, 38541)     0   0.00%  99.93%
# [ 38541, 40808)     0   0.00%  99.93%
# [ 40808, 43075)     0   0.00%  99.93%
# [ 43075, 45341]    11   0.07% 100.00%
#
# Attribute in nodes:
# 	2910 : data:0.9 [CATEGORICAL]
# 	2196 : data:0.4 [CATEGORICAL]
# 	2021 : data:0.6 [CATEGORICAL]
# 	1867 : data:0.1 [CATEGORICAL]
# 	1311 : data:0.7 [CATEGORICAL]
# 	976 : data:0.8 [CATEGORICAL]
# 	971 : data:0.2 [CATEGORICAL]
# 	753 : data:0.3 [CATEGORICAL]
# 	729 : data:0.0 [CATEGORICAL]
# 	688 : data:0.5 [CATEGORICAL]
#
# Attribute in nodes with depth <= 0:
# 	154 : data:0.8 [CATEGORICAL]
# 	93 : data:0.7 [CATEGORICAL]
# 	29 : data:0.3 [CATEGORICAL]
# 	19 : data:0.0 [CATEGORICAL]
# 	4 : data:0.6 [CATEGORICAL]
# 	1 : data:0.5 [CATEGORICAL]
#
# Attribute in nodes with depth <= 1:
# 	274 : data:0.8 [CATEGORICAL]
# 	186 : data:0.7 [CATEGORICAL]
# 	169 : data:0.0 [CATEGORICAL]
# 	142 : data:0.6 [CATEGORICAL]
# 	110 : data:0.3 [CATEGORICAL]
# 	8 : data:0.9 [CATEGORICAL]
# 	5 : data:0.5 [CATEGORICAL]
# 	5 : data:0.4 [CATEGORICAL]
# 	1 : data:0.1 [CATEGORICAL]
#
# Attribute in nodes with depth <= 2:
# 	420 : data:0.7 [CATEGORICAL]
# 	388 : data:0.8 [CATEGORICAL]
# 	324 : data:0.6 [CATEGORICAL]
# 	306 : data:0.0 [CATEGORICAL]
# 	217 : data:0.3 [CATEGORICAL]
# 	211 : data:0.1 [CATEGORICAL]
# 	80 : data:0.9 [CATEGORICAL]
# 	71 : data:0.5 [CATEGORICAL]
# 	61 : data:0.2 [CATEGORICAL]
# 	21 : data:0.4 [CATEGORICAL]
#
# Attribute in nodes with depth <= 3:
# 	782 : data:0.7 [CATEGORICAL]
# 	740 : data:0.9 [CATEGORICAL]
# 	672 : data:0.1 [CATEGORICAL]
# 	641 : data:0.6 [CATEGORICAL]
# 	519 : data:0.8 [CATEGORICAL]
# 	459 : data:0.0 [CATEGORICAL]
# 	295 : data:0.3 [CATEGORICAL]
# 	129 : data:0.2 [CATEGORICAL]
# 	101 : data:0.5 [CATEGORICAL]
# 	85 : data:0.4 [CATEGORICAL]
#
# Attribute in nodes with depth <= 5:
# 	2588 : data:0.9 [CATEGORICAL]
# 	1800 : data:0.6 [CATEGORICAL]
# 	1627 : data:0.1 [CATEGORICAL]
# 	1248 : data:0.7 [CATEGORICAL]
# 	1216 : data:0.4 [CATEGORICAL]
# 	785 : data:0.8 [CATEGORICAL]
# 	671 : data:0.0 [CATEGORICAL]
# 	569 : data:0.2 [CATEGORICAL]
# 	536 : data:0.5 [CATEGORICAL]
# 	493 : data:0.3 [CATEGORICAL]
#
# Condition type in nodes:
# 	14422 : ContainsBitmapCondition
# Condition type in nodes with depth <= 0:
# 	300 : ContainsBitmapCondition
# Condition type in nodes with depth <= 1:
# 	900 : ContainsBitmapCondition
# Condition type in nodes with depth <= 2:
# 	2099 : ContainsBitmapCondition
# Condition type in nodes with depth <= 3:
# 	4423 : ContainsBitmapCondition
# Condition type in nodes with depth <= 5:
# 	11533 : ContainsBitmapCondition
# Node format: NOT_SET
#
# Training OOB:
# 	trees: 1, Out-of-bag evaluation: accuracy:0.996068 logloss:0.141721
# 	trees: 11, Out-of-bag evaluation: accuracy:0.996518 logloss:0.107299
# 	trees: 21, Out-of-bag evaluation: accuracy:0.99654 logloss:0.101638
# 	trees: 31, Out-of-bag evaluation: accuracy:0.996519 logloss:0.100214
# 	trees: 41, Out-of-bag evaluation: accuracy:0.996488 logloss:0.0995099
# 	trees: 51, Out-of-bag evaluation: accuracy:0.996468 logloss:0.0991488
# 	trees: 61, Out-of-bag evaluation: accuracy:0.996561 logloss:0.0984637
# 	trees: 71, Out-of-bag evaluation: accuracy:0.99653 logloss:0.0977859
# 	trees: 81, Out-of-bag evaluation: accuracy:0.996519 logloss:0.097463
# 	trees: 91, Out-of-bag evaluation: accuracy:0.996519 logloss:0.0974525
# 	trees: 101, Out-of-bag evaluation: accuracy:0.99654 logloss:0.0967874
# 	trees: 111, Out-of-bag evaluation: accuracy:0.99655 logloss:0.0967883
# 	trees: 121, Out-of-bag evaluation: accuracy:0.996612 logloss:0.0961159
# 	trees: 131, Out-of-bag evaluation: accuracy:0.996592 logloss:0.0961164
# 	trees: 141, Out-of-bag evaluation: accuracy:0.99655 logloss:0.0961143
# 	trees: 151, Out-of-bag evaluation: accuracy:0.99654 logloss:0.0961
# 	trees: 161, Out-of-bag evaluation: accuracy:0.996509 logloss:0.0961074
# 	trees: 171, Out-of-bag evaluation: accuracy:0.996499 logloss:0.0961045
# 	trees: 181, Out-of-bag evaluation: accuracy:0.99655 logloss:0.0961125
# 	trees: 191, Out-of-bag evaluation: accuracy:0.996581 logloss:0.0961193
# 	trees: 201, Out-of-bag evaluation: accuracy:0.996612 logloss:0.0957848
# 	trees: 211, Out-of-bag evaluation: accuracy:0.996602 logloss:0.095792
# 	trees: 221, Out-of-bag evaluation: accuracy:0.996592 logloss:0.0957705
# 	trees: 231, Out-of-bag evaluation: accuracy:0.996602 logloss:0.0957718
# 	trees: 241, Out-of-bag evaluation: accuracy:0.996612 logloss:0.0957754
# 	trees: 251, Out-of-bag evaluation: accuracy:0.996623 logloss:0.0957772
# 	trees: 261, Out-of-bag evaluation: accuracy:0.996623 logloss:0.095787
# 	trees: 271, Out-of-bag evaluation: accuracy:0.996623 logloss:0.0957959
# 	trees: 281, Out-of-bag evaluation: accuracy:0.996633 logloss:0.0957937
# 	trees: 291, Out-of-bag evaluation: accuracy:0.996633 logloss:0.0957924
# 	trees: 300, Out-of-bag evaluation: accuracy:0.996633 logloss:0.095791
#
# None

# %%
model.save('/content/drive/Shareddrives/datasci/ton_iot/result/RF.tf')
# Out:
# WARNING:absl:Found untraced functions such as call_get_leaves while saving (showing 1 of 1). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/result/RF.tf/assets
# INFO:tensorflow:Assets written to: /content/drive/Shareddrives/datasci/ton_iot/result/RF.tf/assets
